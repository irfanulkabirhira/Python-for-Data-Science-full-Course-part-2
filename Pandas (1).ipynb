# %% [markdown]
# # Pandas

# %% [markdown]
# # pandas Library

# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/irfanulkabirhira/Python-for-Data-Science-full-Course-part-2/main/Titanic-Dataset.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # To Show 1st 5 data

# %%
df.head() #To show 1st 5 dates
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.head(10) #TO show 1st 10 datates
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# # To show Last 5 Data

# %%
df.tail() #To show lst 5 data
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.tail(10) #To show lst 10 data
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# # To show which types of Data is available in the Data sets

# %%
df.dtypes #To see all the data types that has been uesed in this datasets
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# # To know the count, Mean ,Min, Max, what was 25%, 50% ,75% and so on !!!

# %%
df.describe() #To describe the whole Datasets
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # To make my own Data fram

# %%
df[['Name','Sex','Ticket','Cabin','Embarked']] #To creat my own table
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df.dtypes == 'object' # To see which are the String types Data
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %% [markdown]
# # To know which are floating point values

# %%
df[df.dtypes[df.dtypes == 'float64'].index] #To show the floating values
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %% [markdown]
# # To know which are integer point values

# %%
df[df.dtypes[df.dtypes == 'int64'].index] #To show the Integer values
# Out:
#      PassengerId  Survived  Pclass  SibSp  Parch
# 0              1         0       3      1      0
# 1              2         1       1      1      0
# 2              3         1       3      0      0
# 3              4         1       1      1      0
# 4              5         0       3      0      0
# ..           ...       ...     ...    ...    ...
# 886          887         0       2      0      0
# 887          888         1       1      0      0
# 888          889         0       3      1      2
# 889          890         1       1      0      0
# 890          891         0       3      0      0
#
# [891 rows x 5 columns]

# %% [markdown]
# # To show all the Column name

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# # To show a specific column which types are data are available

# %%
df[['Ticket']]
# Out:
#                Ticket
# 0           A/5 21171
# 1            PC 17599
# 2    STON/O2. 3101282
# 3              113803
# 4              373450
# ..                ...
# 886            211536
# 887            112053
# 888        W./C. 6607
# 889            111369
# 890            370376
#
# [891 rows x 1 columns]

# %% [markdown]
# # I want to see 4 numbers Ticket to 15 numbers Ticket So i will use Slicing

# %%
df[['Ticket']][4:16]
# Out:
#        Ticket
# 4      373450
# 5      330877
# 6       17463
# 7      349909
# 8      347742
# 9      237736
# 10    PP 9549
# 11     113783
# 12  A/5. 2151
# 13     347082
# 14     350406
# 15     248706

# %%
df[['Ticket']][4:16:2] #to jump the value
# Out:
#        Ticket
# 4      373450
# 6       17463
# 8      347742
# 10    PP 9549
# 12  A/5. 2151
# 14     350406

# %%
df[['Ticket','Cabin']][4:16]
# Out:
#        Ticket Cabin
# 4      373450   NaN
# 5      330877   NaN
# 6       17463   E46
# 7      349909   NaN
# 8      347742   NaN
# 9      237736   NaN
# 10    PP 9549    G6
# 11     113783  C103
# 12  A/5. 2151   NaN
# 13     347082   NaN
# 14     350406   NaN
# 15     248706   NaN

# %%
df[['Ticket','Cabin']][4:16:2] #To jump the value
# Out:
#        Ticket Cabin
# 4      373450   NaN
# 6       17463   E46
# 8      347742   NaN
# 10    PP 9549    G6
# 12  A/5. 2151   NaN
# 14     350406   NaN

# %%
df[['Ticket','Cabin','Name']][4:16:2] #To jump the value
# Out:
#        Ticket Cabin                                               Name
# 4      373450   NaN                           Allen, Mr. William Henry
# 6       17463   E46                            McCarthy, Mr. Timothy J
# 8      347742   NaN  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 10    PP 9549    G6                    Sandstrom, Miss. Marguerite Rut
# 12  A/5. 2151   NaN                     Saundercock, Mr. William Henry
# 14     350406   NaN               Vestrom, Miss. Hulda Amanda Adolfina

# %% [markdown]
# # To Create New Column

# %%
df['New_Col'] = 0

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['New_Col'] = 2.5

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  Food  \
# 0              1         0       3     0
# 1              2         1       1     0
# 2              3         1       3     0
# 3              4         1       1     0
# 4              5         0       3     0
# ..           ...       ...     ...   ...
# 886          887         0       2     0
# 887          888         1       1     0
# 888          889         0       3     0
# 889          890         1       1     0
# 890          891         0       3     0
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.insert(loc = 3, column = 'Hira', value = 15 )

# %%
df
# Out:
#      PassengerId  Survived  Pclass  Hira  \
# 0              1         0       3    15
# 1              2         1       1    15
# 2              3         1       3    15
# 3              4         1       1    15
# 4              5         0       3    15
# ..           ...       ...     ...   ...
# 886          887         0       2    15
# 887          888         1       1    15
# 888          889         0       3    15
# 889          890         1       1    15
# 890          891         0       3    15
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.insert(loc = 3, column = 'equipments', value = "Oxygen cylinder" )

# %%
df
# Out:
#      PassengerId  Survived  Pclass       equipments  Hira  \
# 0              1         0       3  Oxygen cylinder    15
# 1              2         1       1  Oxygen cylinder    15
# 2              3         1       3  Oxygen cylinder    15
# 3              4         1       1  Oxygen cylinder    15
# 4              5         0       3  Oxygen cylinder    15
# ..           ...       ...     ...              ...   ...
# 886          887         0       2  Oxygen cylinder    15
# 887          888         1       1  Oxygen cylinder    15
# 888          889         0       3  Oxygen cylinder    15
# 889          890         1       1  Oxygen cylinder    15
# 890          891         0       3  Oxygen cylinder    15
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %% [markdown]
# # Pandas Library part-2

# %% [markdown]
# # To see panda is install or not

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
a= df['Name'][0:10]

# %%
a
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
l = ['Hira', 'a2', 'a3', 'a4','a5','a6','a7','a8','a10']

# %%
pd.Series(a,index = l)
# Out:
# Hira    NaN
# a2      NaN
# a3      NaN
# a4      NaN
# a5      NaN
# a6      NaN
# a7      NaN
# a8      NaN
# a10     NaN
# Name: Name, dtype: object

# %%
pd.Series(list(a),index = l)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 pd.Series(list(a),index = l)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\series.py:503, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     501     index = default_index(len(data))
#     502 elif is_list_like(data):
# --> 503     com.require_length_match(data, index)
#     505 # create/copy the manager
#     506 if isinstance(data, (SingleBlockManager, SingleArrayManager)):
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\common.py:561, in require_length_match(data, index)
#     557 """
#     558 Check the length of data matches the length of the index.
#     559 """
#     560 if len(data) != len(index):
# --> 561     raise ValueError(
#     562         "Length of values "
#     563         f"({len(data)}) "
# ...

# %%
m1 = pd.Series([100,200,300,400,500] , index = [1, 2, 3, 4, 5])

# %%
m1
# Out:
# 1    100
# 2    200
# 3    300
# 4    400
# 5    500
# dtype: int64

# %%
m2 = pd.Series([600, 700, 800, 900, 1000] , index = [1, 2, 3, 4, 5] )

# %%
m2
# Out:
# 1     600
# 2     700
# 3     800
# 4     900
# 5    1000
# dtype: int64

# %%
m3 = pd.concat([m1, m2]) # Concatinate m1 and m2

# %%
m3
# Out:
# 1     100
# 2     200
# 3     300
# 4     400
# 5     500
# 1     600
# 2     700
# 3     800
# 4     900
# 5    1000
# dtype: int64

# %%
m3[1] # to know the first wala element
# Out:
# 1    100
# 1    600
# dtype: int64

# %%
m1*m2 # to multiply the m1 and m2
# Out:
# 1     60000
# 2    140000
# 3    240000
# 4    360000
# 5    500000
# dtype: int64

# %%
m1+m2 #Addition
# Out:
# 1     700
# 2     900
# 3    1100
# 4    1300
# 5    1500
# dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass       equipments  Hira  \
# 0            1         0       3  Oxygen cylinder    15
# 1            2         1       1  Oxygen cylinder    15
# 2            3         1       3  Oxygen cylinder    15
# 3            4         1       1  Oxygen cylinder    15
# 4            5         0       3  Oxygen cylinder    15
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  New_Col
# 0      0         A/5 21171   7.2500   NaN        S        0
# 1      0          PC 17599  71.2833   C85        C        0
# ...

# %% [markdown]
# # To delete the Column we use -> axix 1 & to Delete the Row we use -> 0

# %%
df.drop("PassengerId",axis = 1)
# Out:
#      Survived  Pclass       equipments  Hira  \
# 0           0       3  Oxygen cylinder    15
# 1           1       1  Oxygen cylinder    15
# 2           1       3  Oxygen cylinder    15
# 3           1       1  Oxygen cylinder    15
# 4           0       3  Oxygen cylinder    15
# ..        ...     ...              ...   ...
# 886         0       2  Oxygen cylinder    15
# 887         1       1  Oxygen cylinder    15
# 888         0       3  Oxygen cylinder    15
# 889         1       1  Oxygen cylinder    15
# 890         0       3  Oxygen cylinder    15
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %% [markdown]
# # TO see permanently Deleted or not

# %%
df.head() # No permanently not deleted
# Out:
#    PassengerId  Survived  Pclass       equipments  Hira  \
# 0            1         0       3  Oxygen cylinder    15
# 1            2         1       1  Oxygen cylinder    15
# 2            3         1       3  Oxygen cylinder    15
# 3            4         1       1  Oxygen cylinder    15
# 4            5         0       3  Oxygen cylinder    15
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  New_Col
# 0      0         A/5 21171   7.2500   NaN        S        0
# 1      0          PC 17599  71.2833   C85        C        0
# ...

# %% [markdown]
# # To Delete this permanently

# %%
df.drop("Survived",axis = 1 , inplace = True) # Yes , Permanently Deleted

# %%
df
# Out:
#      PassengerId  Pclass       equipments  Hira  \
# 0              1       3  Oxygen cylinder    15
# 1              2       1  Oxygen cylinder    15
# 2              3       3  Oxygen cylinder    15
# 3              4       1  Oxygen cylinder    15
# 4              5       3  Oxygen cylinder    15
# ..           ...     ...              ...   ...
# 886          887       2  Oxygen cylinder    15
# 887          888       1  Oxygen cylinder    15
# 888          889       3  Oxygen cylinder    15
# 889          890       1  Oxygen cylinder    15
# 890          891       3  Oxygen cylinder    15
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %% [markdown]
# # Row Delete

# %%
df.drop(3) #But not deleted Permenantly
# Out:
#      PassengerId  Pclass       equipments  Hira  \
# 0              1       3  Oxygen cylinder    15
# 1              2       1  Oxygen cylinder    15
# 2              3       3  Oxygen cylinder    15
# 4              5       3  Oxygen cylinder    15
# 5              6       3  Oxygen cylinder    15
# ..           ...     ...              ...   ...
# 886          887       2  Oxygen cylinder    15
# 887          888       1  Oxygen cylinder    15
# 888          889       3  Oxygen cylinder    15
# 889          890       1  Oxygen cylinder    15
# 890          891       3  Oxygen cylinder    15
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.head()
# Out:
#    PassengerId  Pclass       equipments  Hira  \
# 0            1       3  Oxygen cylinder    15
# 1            2       1  Oxygen cylinder    15
# 2            3       3  Oxygen cylinder    15
# 3            4       1  Oxygen cylinder    15
# 4            5       3  Oxygen cylinder    15
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  New_Col
# 0      0         A/5 21171   7.2500   NaN        S        0
# 1      0          PC 17599  71.2833   C85        C        0
# ...

# %%
df.drop(3, inplace = True) #But not deleted Permenantly

# %%
df
# Out:
#      PassengerId  Pclass       equipments  Hira  \
# 0              1       3  Oxygen cylinder    15
# 1              2       1  Oxygen cylinder    15
# 2              3       3  Oxygen cylinder    15
# 4              5       3  Oxygen cylinder    15
# 5              6       3  Oxygen cylinder    15
# ..           ...     ...              ...   ...
# 886          887       2  Oxygen cylinder    15
# 887          888       1  Oxygen cylinder    15
# 888          889       3  Oxygen cylinder    15
# 889          890       1  Oxygen cylinder    15
# 890          891       3  Oxygen cylinder    15
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %% [markdown]
# # convert e particular column to Index

# %%
df.set_index('Name')
# Out:
#                                                     PassengerId  Pclass  \
# Name
# Braund, Mr. Owen Harris                                       1       3
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2       1
# Heikkinen, Miss. Laina                                        3       3
# Allen, Mr. William Henry                                      5       3
# Moran, Mr. James                                              6       3
# ...                                                         ...     ...
# Montvila, Rev. Juozas                                       887       2
# Graham, Miss. Margaret Edith                                888       1
# Johnston, Miss. Catherine Helen "Carrie"                    889       3
# Behr, Mr. Karl Howell                                       890       1
# Dooley, Mr. Patrick                                         891       3
#
#                                                          equipments  Hira  \
# Name
# ...

# %%
df # To see index position is permanent or not
# Out:
#      PassengerId  Pclass       equipments  Hira  \
# 0              1       3  Oxygen cylinder    15
# 1              2       1  Oxygen cylinder    15
# 2              3       3  Oxygen cylinder    15
# 4              5       3  Oxygen cylinder    15
# 5              6       3  Oxygen cylinder    15
# ..           ...     ...              ...   ...
# 886          887       2  Oxygen cylinder    15
# 887          888       1  Oxygen cylinder    15
# 888          889       3  Oxygen cylinder    15
# 889          890       1  Oxygen cylinder    15
# 890          891       3  Oxygen cylinder    15
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
df.set_index('Name', inplace = True) # Permanently Changed the Index

# %%
df
# Out:
#                                                     PassengerId  Pclass  \
# Name
# Braund, Mr. Owen Harris                                       1       3
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2       1
# Heikkinen, Miss. Laina                                        3       3
# Allen, Mr. William Henry                                      5       3
# Moran, Mr. James                                              6       3
# ...                                                         ...     ...
# Montvila, Rev. Juozas                                       887       2
# Graham, Miss. Margaret Edith                                888       1
# Johnston, Miss. Catherine Helen "Carrie"                    889       3
# Behr, Mr. Karl Howell                                       890       1
# Dooley, Mr. Patrick                                         891       3
#
#                                                          equipments  Hira  \
# Name
# ...

# %%
df.head()
# Out:
#                                                     PassengerId  Pclass  \
# Name
# Braund, Mr. Owen Harris                                       1       3
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2       1
# Heikkinen, Miss. Laina                                        3       3
# Allen, Mr. William Henry                                      5       3
# Moran, Mr. James                                              6       3
#
#                                                          equipments  Hira  \
# Name
# Braund, Mr. Owen Harris                             Oxygen cylinder    15
# Cumings, Mrs. John Bradley (Florence Briggs Tha...  Oxygen cylinder    15
# Heikkinen, Miss. Laina                              Oxygen cylinder    15
# Allen, Mr. William Henry                            Oxygen cylinder    15
# Moran, Mr. James                                    Oxygen cylinder    15
#
# ...

# %% [markdown]
# # Reset Index

# %%
df.reset_index()
# Out:
#                                                   Name  PassengerId  Pclass  \
# 0                              Braund, Mr. Owen Harris            1       3
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2       1
# 2                               Heikkinen, Miss. Laina            3       3
# 3                             Allen, Mr. William Henry            5       3
# 4                                     Moran, Mr. James            6       3
# ..                                                 ...          ...     ...
# 885                              Montvila, Rev. Juozas          887       2
# 886                       Graham, Miss. Margaret Edith          888       1
# 887           Johnston, Miss. Catherine Helen "Carrie"          889       3
# 888                              Behr, Mr. Karl Howell          890       1
# 889                                Dooley, Mr. Patrick          891       3
#
# ...

# %% [markdown]
# # To make a Data Frame from the  Dictionary

# %%
d = { "key1" : [1, 2, 3, 4, 5],
     "key2" : [6, 7, 8, 9, 10], 
    "key3" : [11,12,13,14,15]
    }

# %%
print (d)
# Out:
# {'key1': [1, 2, 3, 4, 5], 'key2': [6, 7, 8, 9, 10], 'key3': [11, 12, 13, 14, 15]}

# %%
pd.DataFrame(d)
# Out:
#    key1  key2  key3
# 0     1     6    11
# 1     2     7    12
# 2     3     8    13
# 3     4     9    14
# 4     5    10    15

# %%
df
# Out:
#                                                     PassengerId  Pclass  \
# Name
# Braund, Mr. Owen Harris                                       1       3
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2       1
# Heikkinen, Miss. Laina                                        3       3
# Allen, Mr. William Henry                                      5       3
# Moran, Mr. James                                              6       3
# ...                                                         ...     ...
# Montvila, Rev. Juozas                                       887       2
# Graham, Miss. Margaret Edith                                888       1
# Johnston, Miss. Catherine Helen "Carrie"                    889       3
# Behr, Mr. Karl Howell                                       890       1
# Dooley, Mr. Patrick                                         891       3
#
#                                                          equipments  Hira  \
# Name
# ...

# %% [markdown]
# # To Drop the missing Value (NaN ) But delete the Row

# %%
df.dropna() # But not permanent
# Out:
#                                                     PassengerId  Pclass  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2       1
# McCarthy, Mr. Timothy J                                       7       1
# Sandstrom, Miss. Marguerite Rut                              11       3
# Bonnell, Miss. Elizabeth                                     12       1
# Beesley, Mr. Lawrence                                        22       2
# ...                                                         ...     ...
# Beckwith, Mrs. Richard Leonard (Sallie Monypeny)            872       1
# Carlsson, Mr. Frans Olof                                    873       1
# Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)               880       1
# Graham, Miss. Margaret Edith                                888       1
# Behr, Mr. Karl Howell                                       890       1
#
#                                                          equipments  Hira  \
# Name
# ...

# %%
df
# Out:
#                                                     PassengerId  Pclass  \
# Name
# Braund, Mr. Owen Harris                                       1       3
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2       1
# Heikkinen, Miss. Laina                                        3       3
# Allen, Mr. William Henry                                      5       3
# Moran, Mr. James                                              6       3
# ...                                                         ...     ...
# Montvila, Rev. Juozas                                       887       2
# Graham, Miss. Margaret Edith                                888       1
# Johnston, Miss. Catherine Helen "Carrie"                    889       3
# Behr, Mr. Karl Howell                                       890       1
# Dooley, Mr. Patrick                                         891       3
#
#                                                          equipments  Hira  \
# Name
# ...

# %%
df.dropna(inplace= True) # For the permanent  changes

# %%
df
# Out:
#                                                     PassengerId  Pclass  \
# Name
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2       1
# McCarthy, Mr. Timothy J                                       7       1
# Sandstrom, Miss. Marguerite Rut                              11       3
# Bonnell, Miss. Elizabeth                                     12       1
# Beesley, Mr. Lawrence                                        22       2
# ...                                                         ...     ...
# Beckwith, Mrs. Richard Leonard (Sallie Monypeny)            872       1
# Carlsson, Mr. Frans Olof                                    873       1
# Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)               880       1
# Graham, Miss. Margaret Edith                                888       1
# Behr, Mr. Karl Howell                                       890       1
#
#                                                          equipments  Hira  \
# Name
# ...

# %% [markdown]
# # Taking the CSV file again so that , it looks better

# %%
df2 =pd.read_csv("https://raw.githubusercontent.com/irfanulkabirhira/Python-for-Data-Science-full-Course-part-2/main/Titanic-Dataset.csv")

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # Task is to delete the column which are missing value (Nan)

# %%
df2.dropna(axis=1) # Not change permanently
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2.dropna(axis=1, inplace = True)

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  SibSp  Parch  \
# 0                              Braund, Mr. Owen Harris    male      1      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                               Heikkinen, Miss. Laina  female      0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                             Allen, Mr. William Henry    male      0      0
# ...

# %% [markdown]
# # In missing value i want to Place my name Hira

# %% [markdown]
# as i have done permanently changed the data , so have to take again the Data fresh , So i will take df3

# %%
df3 = pd.read_csv("https://raw.githubusercontent.com/irfanulkabirhira/Python-for-Data-Science-full-Course-part-2/main/Titanic-Dataset.csv")

# %%
df3
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # To place my name in missing value or NaN position , what i will do is....

# %%
df3.fillna("Hira") # But not permanent Change
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df3.fillna("Hira", inplace = True) # But Now permanently Change
# Out:
# C:\Users\hirak\AppData\Local\Temp\ipykernel_33848\1330969601.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Hira' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df3.fillna("Hira", inplace = True) # But Now permanently Change

# %%
df3
